# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceGhotar/Image-Compression/blob/main/Image_Compression_using_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA
from skimage import io

# %%
img = cv2.cvtColor(cv2.imread("deepak.jpeg"),cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (420, 360, 3)

# %%
plt.imshow(img)

# %%
r,g,b =cv2.split(img)

# %%
r,g,b =r/255,g/255,b/255

# %%
plt.imshow(r)

# %%
plt.imshow(g)

# %%
plt.imshow(b)

# %%
pca_components = 50
pca_r = PCA(n_components=pca_components)
reduced_r = pca_r.fit_transform(r)

# %%
reduced_r.shape
# Out:
# (420, 50)

# %%
pca_g = PCA(n_components=pca_components)
reduced_g = pca_g.fit_transform(g)

pca_b = PCA(n_components=pca_components)
reduced_b = pca_b.fit_transform(b)

# %%
combined = np.array([reduced_r,reduced_g,reduced_b])

# %%
combined.shape
# Out:
# (3, 420, 50)

# %%
reconstructed_r = pca_r.inverse_transform(reduced_r)
reconstructed_r.shape
# Out:
# (420, 360)

# %%
reconstructed_g = pca_g.inverse_transform(reduced_g)
reconstructed_b = pca_b.inverse_transform(reduced_b)

# %%
img_reconstructed = (cv2.merge((reconstructed_r,reconstructed_g,reconstructed_b)))

# %%
io.imshow(img_reconstructed)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_reconstructed.shape
# Out:
# (420, 360, 3)

# %%
io.imsave("img_reconstructed.jpeg",img_reconstructed)
# Out:
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [-0.08251898440131683, 1.1102384410143724]. Convert image to uint8 prior to saving to suppress this warning.
